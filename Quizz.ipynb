# %%
#Imputer en remplacant les valeurs manquantes par la moy
list_random = [None, 2, 3, 12, 5, 6, None]

class Imputer: #On créer notre class
    def __init__(self, list):
        self.list = list

    def avg(self):
        clean_list = [
            valeur for valeur in self.list 
            if isinstance(valeur, (int, float)) #On lui explique que les valeurs int & float ne seront pas remplacer dans self.list
        ]
        somme = sum(clean_list) #sum de clean_list sous le nom somme
        compteur = len(clean_list) #len de clean list sous le nom compteur
        moy = somme / compteur #création de la moyenne ( import statistic ou numpy fonctionne aussi pour plus de facilité )
        remp_list = [] #création de la liste de remplissage avec les conditions
        for i in self.list:
            if i is None:
                remp_list.append(moy) #si [i] est None on le remplace par la moyenne via .append
            else:
                remp_list.append(i) #si c'est autre chose que None on lui dis de gardé sa valeur (i)
        return remp_list #retour a la liste une fois les conditions appliqué

imputer = Imputer(list_random) #création de notre imputer avec toute nos conditions de la class Imputer sur notre list_random
imputer_list_avg = imputer.avg #on créer notre liste average

print(imputer_list_avg()) #on print pour affiché le resultat

#EtienneCode
# Out:
# [5.6, 2, 3, 12, 5, 6, 5.6]

# %%
class Imputer:
    def __init__(self, list):
        self.list = list
    
    def avg(self):
        clean_list = [x for x in self.list if x is not None]
        if not clean_list:
            return self.list
        average = sum(clean_list) / len(clean_list) #
        for i in range(len(self.list)):
            if self.list[i] is None:
                self.list[i] = average
            else: 
                pass #Ne pas touchez si else
        
        return self.list
    
test_list = [10, 20, None, 45, None, 12, 28, None]
print(f"Original Data: {test_list} ")
imputer = Imputer(test_list)

avg_test_list = imputer.avg()
print(f"Averaged Data:{avg_test_list}")

#Bilelcode
# Out:
# Original Data: [10, 20, None, 45, None, 12, 28, None]
# Averaged Data:[10, 20, 23.0, 45, 23.0, 12, 28, 23.0]

# %%
nb_de_chances = 3

print("Voici notre quiz, tu as trois chances !")

if nb_de_chances > 0:
    question1= input("Combien de fois la France a gagné la coupe du monde ? ")
    while question1 != "2":
        nb_de_chances -= 1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question1 = input("Combien de fois la France a gagné la coupe du monde ? ")

if nb_de_chances > 0:
    question2 = input("Quand a été fondé Apple ? ")
    while question2 != "1976":
        nb_de_chances -=1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question2 = input("Quand a été fondé Apple ? ")


if nb_de_chances > 0:
    question3 = input("Qui a fondé SpaceX ? ")
    question3 = question3.lower()
    while question3 != "elon musk":
        nb_de_chances -=1
        print("Dommage ! Il te reste {} chances".format(nb_de_chances))
        if nb_de_chances == 0:
            print("Oh non ! Tu as perdu le jeu...")
            break
        question3 = input("Qui a fondé SpaceX ? ")
        question3 = question3.lower()

if nb_de_chances > 0:
    print("Bravo ! Tu as gagné le quiz !")
# Out:
# Voici notre quiz, tu as trois chances !
# Bravo ! Tu as gagné le quiz !

# %%
def question(question, reponse, nb_chances_restantes):
    """
    Pose une question à l'utilisateur et gère la vérification et chances restantes.

    question: la question à afficher.
    reponse: La réponse correcte (doit être une chaîne de caractères).
    nb_chances_restantes: Le nombre total de chances restantes pour le quiz.
    :return: Le nombre de chances restantes après avoir répondu à la question.
    """
    if nb_chances_restantes <= 0:
        return 0

    reponse_correcte = False #Ici on créer la fonction reponse_correct = false pour la remplacer par = True plus tard
    
    while not reponse_correcte and nb_chances_restantes > 0: #on set up nos conditions, ici tant qu'on a des chances et pas la bonne reponse on replay la question
        reponse_utilisateur = input(f"{question}") #input permet de créer la question via la fonction f-string (f"question")
        if reponse_utilisateur == reponse: #si reponse correcte
            print("Correct ! Passons a la prochaine question.")
            reponse_correcte = True #c'est ici qu'on remplace notre condition False par True nous permettant de passer la prochaine question
        else:
            nb_chances_restantes -= 1 #permet de reduire de 1 le nombre de chance a chaque fail
            if nb_chances_restantes > 0:
                print(f"Wrong ! Il te reste {nb_chances_restantes} chance(s).") 
            else:
                print("Oh non ! Tu as perdu le jeu!") #permet grace au return en dessous de ne pas avoir besoin de la fonction break

    return nb_chances_restantes #return toujours au nombre de chance c'est ce qui définis si on continu ou arrête le quizz 


def quizz():
    """
    Exécute le quiz.
    """
    nb_de_chances = 3
    print("Voici notre quiz ! Tu as trois chances au total pour toutes les questions.") 
    #ici on créer notre def quizz pour lancé le quizz on commence avec 3 chances
    nb_de_chances = question(
        "Combien de fois la France a gagné la coupe du monde ? ", #on met la question & la reponse attention la virgule pour séparer les 2
        "2", 
        nb_de_chances
    )
    if nb_de_chances <= 0:
        return #on précise a chaque fois que si le nombre de chance tombe a 0 on recommence tout

    nb_de_chances = question(
        "Quand a été fondé Apple ? ", 
        "1976", 
        nb_de_chances
    )

    if nb_de_chances <= 0:
        return

    
    nb_de_chances = question(
        "Qui a fondé SpaceX ? (Majuscule au début pour le nom & prénom) ", #précise majuscule mais on aurais pu use un .lower qui permet de transformer
        #chaque réponse en miniscule 
        "Elon Musk", 
        nb_de_chances,
    )
    
    print("Résultat Final:")
    if nb_de_chances == 3:
        print("Bravo ! Tu as gagné le quiz avec toute tes chances restantes!")
    elif nb_de_chances == 2:
        print("Bravo ! Tu as gagné le quizz avec 2 chances restantes")
    elif nb_de_chances == 1:
        print("Bravo ! Tu as gagné le quizz avec 1 chances restantes") #petit amusement de ma part pour préciser au joueur le nombre de chance restante

quizz()
# Out:
# Voici notre quiz ! Tu as trois chances au total pour toutes les questions.
# Wrong ! Il te reste 2 chance(s).
# Wrong ! Il te reste 1 chance(s).
# Correct ! Passons a la prochaine question.
# Correct ! Passons a la prochaine question.
# Correct ! Passons a la prochaine question.
# Résultat Final:
# Bravo ! Tu as gagné le quizz avec 1 chances restantes
